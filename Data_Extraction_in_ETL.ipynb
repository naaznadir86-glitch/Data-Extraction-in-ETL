# %%
# 1. Types of data sources used in ETL
# Ans. 1.Big Data Sources - Example --Azure Data Lake,Hadoop
       2.Databases - Example -- MySQL,Oracle
       3.Cloud Sources - Example -- Google analytics
       4. APIs - Example -- JSON,XML feeds

# %% [markdown]
# #2. What is data extraction and its role in ETL pipeline
# # Ans. Extraction = collecting raw data from sources ETL
#
#
# *    Collects data from datasources
# *    ensures transformation and loading
# *    clean starting point for reporting and analysing

# %% [markdown]
# #3. Difference between CSV and Excel
# # Ans. CSV- plain text,comma seperated values,handles large data efficiently,   has only raw data.
#        Excel -Binary file with sheets,formulas and formatting,limited by excel row and column limits,can include formulas multiple sheets formatting

# %% [markdown]
# #4. Steps in extracting data from a relational database
# #Ans. 1. Connect to the database
#       2. Select the required tables or views
#       3. Write queries
#       4. Extract the data
#       5. Validate the extraction

# %% [markdown]
# #5. Three common challanges faced during extraction
# # Ans. 1. Data Quality issues- null value,duplicate records
#        2. Multiple and hetergenous resources - Data comes from different sources with different databases
#        3.Performance & Volume issues - Large datasets can slow extractions.

# %% [markdown]
# #6. What are APIs ? Explain how APIs help in real time data extraction
# # Ans. APIs- are interfaces that allow different software application to communicate and exchange data
#       Enable ETL tools to pull data directly from webs apps services
#       Provide up to date data on demand without manual downloads
#       Useful for real time dashboards and analytics

# %% [markdown]
# # 7. Why are databases preferred for enterprise level data extraction ?
# # Ans. 1. Structured and organised data
#        2. Handles large volumes efficiently
#        3. Supports complex querries
#        4. Secure and controlled access

# %% [markdown]
# #8. Steps to Extract data from CSV file 1GB
# # Ans. Load in chunks > Select only needed data > Validate > Use efficient tools > Monitor performance
